# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
blood_sugar = [124, 76, 89, 130, 159, 58, 83, 105, 133, 84, 79, 81, 139]
plt.hist(blood_sugar, rwidth=0.8)
# Out:
# (array([1., 1., 4., 1., 1., 0., 1., 2., 1., 1.]),
#  array([ 58. ,  68.1,  78.2,  88.3,  98.4, 108.5, 118.6, 128.7, 138.8,
#         148.9, 159. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(blood_sugar,rwidth=0.5,bins=5)
# Out:
# (array([2., 5., 1., 3., 2.]),
#  array([ 58. ,  78.2,  98.4, 118.6, 138.8, 159. ]),
#  <a list of 5 Patch objects>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color='B')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   """
# (array([4., 2., 3.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'])
plt.legend()

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')
# Out:
# (array([4., 2., 3.]), array([ 80, 100, 125, 150]), <a list of 1 Patch objects>)

# %%
plt.xlabel("Number Of Patients")
plt.ylabel("Sugar Level")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.90, orientation='horizontal')
# Out:
# (array([4., 2., 3.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)
